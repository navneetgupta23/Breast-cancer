# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter('ignore')

# %%
df = pd.read_csv('breast_cancer_dataframe.csv')
df.head()
# Out:
#    Unnamed: 0  mean radius  mean texture  mean perimeter  mean area  \
# 0           0        17.99         10.38          122.80     1001.0
# 1           1        20.57         17.77          132.90     1326.0
# 2           2        19.69         21.25          130.00     1203.0
# 3           3        11.42         20.38           77.58      386.1
# 4           4        20.29         14.34          135.10     1297.0
#
#    mean smoothness  mean compactness  mean concavity  mean concave points  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    mean symmetry  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
df.drop('Unnamed: 0', axis=1,inplace=True)

# %%
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
df['target'].dtype
# Out:
# dtype('float64')

# %%
df['target'] = df['target'].astype('int')

# %%
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
sns.countplot(x='target',data=df)
# Out:
# <AxesSubplot:xlabel='target', ylabel='count'>

# %%
len(df[df['target'] == 0])
# Out:
# 212

# %%
len(df[df['target'] == 1])
# Out:
# 357

# %%
#malignant = harmful
#benign = not harmful
#0 = m
#1 = B

# %%
df['target'] = df['target'].replace({0:'M', 1:'B'})
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
sns.countplot(x='target',data=df)
# Out:
# <AxesSubplot:xlabel='target', ylabel='count'>

# %%
df.describe().T
# Out:
#                          count        mean         std         min  \
# mean radius              569.0   14.127292    3.524049    6.981000
# mean texture             569.0   19.289649    4.301036    9.710000
# mean perimeter           569.0   91.969033   24.298981   43.790000
# mean area                569.0  654.889104  351.914129  143.500000
# mean smoothness          569.0    0.096360    0.014064    0.052630
# mean compactness         569.0    0.104341    0.052813    0.019380
# mean concavity           569.0    0.088799    0.079720    0.000000
# mean concave points      569.0    0.048919    0.038803    0.000000
# mean symmetry            569.0    0.181162    0.027414    0.106000
# mean fractal dimension   569.0    0.062798    0.007060    0.049960
# radius error             569.0    0.405172    0.277313    0.111500
# texture error            569.0    1.216853    0.551648    0.360200
# perimeter error          569.0    2.866059    2.021855    0.757000
# ...

# %%
df.shape
# Out:
# (569, 31)

# %%
df.isnull().sum()
# Out:
# mean radius                0
# mean texture               0
# mean perimeter             0
# mean area                  0
# mean smoothness            0
# mean compactness           0
# mean concavity             0
# mean concave points        0
# mean symmetry              0
# mean fractal dimension     0
# radius error               0
# texture error              0
# perimeter error            0
# area error                 0
# smoothness error           0
# compactness error          0
# concavity error            0
# concave points error       0
# symmetry error             0
# fractal dimension error    0
# worst radius               0
# worst texture              0
# worst perimeter            0
# worst area                 0
# worst smoothness           0
# worst compactness          0
# worst concavity            0
# worst concave points       0
# worst symmetry             0
# worst fractal dimension    0
# target                     0
# dtype: int64

# %%
data_stan = df.drop('target', axis = 1)
data_stan.shape
# Out:
# (569, 30)

# %%
data_stan = (data_stan-data_stan.mean())/data_stan.std()

# %%
data_stan.describe().T
# Out:
#                          count          mean  std       min       25%  \
# mean radius              569.0 -3.136331e-15  1.0 -2.027864 -0.688779
# mean texture             569.0 -6.558316e-15  1.0 -2.227289 -0.725325
# mean perimeter           569.0 -7.012551e-16  1.0 -1.982759 -0.691347
# mean area                569.0 -8.339355e-16  1.0 -1.453164 -0.666609
# mean smoothness          569.0  6.120470e-15  1.0 -3.109349 -0.710338
# mean compactness         569.0 -1.074321e-15  1.0 -1.608721 -0.746429
# mean concavity           569.0 -4.031144e-16  1.0 -1.113893 -0.743094
# mean concave points      569.0  1.006030e-15  1.0 -1.260710 -0.737295
# mean symmetry            569.0 -1.888550e-15  1.0 -2.741705 -0.702621
# mean fractal dimension   569.0  4.860396e-16  1.0 -1.818265 -0.722004
# radius error             569.0 -9.998836e-16  1.0 -1.058992 -0.623022
# texture error            569.0 -9.782255e-16  1.0 -1.552898 -0.694198
# ...

# %%
data_stan.isnull().sum()
# Out:
# mean radius                0
# mean texture               0
# mean perimeter             0
# mean area                  0
# mean smoothness            0
# mean compactness           0
# mean concavity             0
# mean concave points        0
# mean symmetry              0
# mean fractal dimension     0
# radius error               0
# texture error              0
# perimeter error            0
# area error                 0
# smoothness error           0
# compactness error          0
# concavity error            0
# concave points error       0
# symmetry error             0
# fractal dimension error    0
# worst radius               0
# worst texture              0
# worst perimeter            0
# worst area                 0
# worst smoothness           0
# worst compactness          0
# worst concavity            0
# worst concave points       0
# worst symmetry             0
# worst fractal dimension    0
# dtype: int64

# %%
data1 = pd.concat([data_stan.iloc[:,0:10], df['target']],axis=1)
data1.shape
# Out:
# (569, 11)

# %%
data1.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0     1.096100     -2.071512        1.268817   0.983510         1.567087
# 1     1.828212     -0.353322        1.684473   1.907030        -0.826235
# 2     1.578499      0.455786        1.565126   1.557513         0.941382
# 3    -0.768233      0.253509       -0.592166  -0.763792         3.280667
# 4     1.748758     -1.150804        1.775011   1.824624         0.280125
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0          3.280628        2.650542             2.530249       2.215566
# 1         -0.486643       -0.023825             0.547662       0.001391
# 2          1.052000        1.362280             2.035440       0.938859
# 3          3.399917        1.914213             1.450431       2.864862
# 4          0.538866        1.369806             1.427237      -0.009552
#
#    mean fractal dimension target
# 0                2.253764      M
# ...

# %%
data1 = pd.melt(data1, id_vars = 'target', value_name = 'value',var_name='features' )
data1.head()
# Out:
#   target     features     value
# 0      M  mean radius  1.096100
# 1      M  mean radius  1.828212
# 2      M  mean radius  1.578499
# 3      M  mean radius -0.768233
# 4      M  mean radius  1.748758

# %%
plt.figure(figsize = (10,5))
sns.violinplot(x='features', y='value', data=data1, inner = 'quartile', hue = 'target', split = True)
plt.xticks(rotation=90)
plt.show()

# %%
data2 = pd.concat([data_stan.iloc[:,10:20], df['target']],axis=1)
data2.shape
# Out:
# (569, 11)

# %%
data2.head()
# Out:
#    radius error  texture error  perimeter error  area error  smoothness error  \
# 0      2.487545      -0.564768         2.830540    2.485391         -0.213814
# 1      0.498816      -0.875473         0.263095    0.741749         -0.604819
# 2      1.227596      -0.779398         0.850180    1.180298         -0.296744
# 3      0.326087      -0.110312         0.286341   -0.288125          0.689095
# 4      1.269426      -0.789549         1.272070    1.189310          1.481763
#
#    compactness error  concavity error  concave points error  symmetry error  \
# 0           1.315704         0.723390              0.660239        1.147747
# 1          -0.692317        -0.440393              0.259933       -0.804742
# 2           0.814257         0.212889              1.423575        0.236827
# 3           2.741868         0.818798              1.114027        4.728520
# 4          -0.048477         0.827742              1.143199       -0.360775
#
#    fractal dimension error target
# ...

# %%
data2 = pd.melt(data2, id_vars = 'target', value_name = 'value',var_name='features' )
data2.head()
# Out:
#   target      features     value
# 0      M  radius error  2.487545
# 1      M  radius error  0.498816
# 2      M  radius error  1.227596
# 3      M  radius error  0.326087
# 4      M  radius error  1.269426

# %%
plt.figure(figsize = (10,5))
sns.violinplot(x='features', y='value', data=data2, inner = 'quartile', hue = 'target', split = True)
plt.xticks(rotation=90)
plt.show()

# %%
data3 = pd.concat([data_stan.iloc[:,20:30], df['target']],axis=1)
data3.shape
# Out:
# (569, 11)

# %%
data3.head()
# Out:
#    worst radius  worst texture  worst perimeter  worst area  worst smoothness  \
# 0      1.885031      -1.358098         2.301575    1.999478          1.306537
# 1      1.804340      -0.368879         1.533776    1.888827         -0.375282
# 2      1.510541      -0.023953         1.346291    1.455004          0.526944
# 3     -0.281217       0.133866        -0.249720   -0.549538          3.391291
# 4      1.297434      -1.465481         1.337363    1.219651          0.220362
#
#    worst compactness  worst concavity  worst concave points  worst symmetry  \
# 0           2.614365         2.107672              2.294058        2.748204
# 1          -0.430066        -0.146620              1.086129       -0.243675
# 2           1.081980         0.854222              1.953282        1.151242
# 3           3.889975         1.987839              2.173873        6.040726
# 4          -0.313119         0.612640              0.728618       -0.867590
#
#    worst fractal dimension target
# ...

# %%
data3 = pd.melt(data3, id_vars = 'target', value_name = 'value',var_name='features' )
data3.head()
# Out:
#   target      features     value
# 0      M  worst radius  1.885031
# 1      M  worst radius  1.804340
# 2      M  worst radius  1.510541
# 3      M  worst radius -0.281217
# 4      M  worst radius  1.297434

# %%
plt.figure(figsize = (10,5))
sns.violinplot(x='features', y='value', data=data3, inner = 'quartile', hue = 'target', split = True)
plt.xticks(rotation=90)
plt.show()

# %%
sns.lmplot(x = 'worst concavity', y = 'worst concave points', data = data_stan)

# %%
corr = data_stan.corr()
mask = np.triu(np.ones_like(corr, dtype=np.bool))
f, ax = plt.subplots(figsize=(23, 13))
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(corr, annot=True,fmt='.2f',mask=mask, cmap=cmap, ax=ax);

# %%
plt.figure(figsize = (10,5))
sns.swarmplot(x='features', y='value', hue = 'target', data=data1, size=2)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize = (10,5))
sns.swarmplot(x='features', y='value', hue = 'target', data=data2, size=2)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize = (10,5))
sns.swarmplot(x='features', y='value', hue = 'target', data=data3, size=2)
plt.xticks(rotation=90)
plt.show()

# %%
drop = ['mean compactness', 'mean concave points', 'radius error', 'perimeter error', 'worst radius', 
        'worst perimeter', 'worst compactness', 'worst concave points', 'compactness error', 'concave points error', 
    'worst area', 'mean perimeter', 'mean radius']
data_stan = data_stan.drop(drop, axis=1)
data_stan.shape
# Out:
# (569, 17)

# %%
data_stan.columns
# Out:
# Index(['mean texture', 'mean area', 'mean smoothness', 'mean concavity',
#        'mean symmetry', 'mean fractal dimension', 'texture error',
#        'area error', 'smoothness error', 'concavity error', 'symmetry error',
#        'fractal dimension error', 'worst texture', 'worst smoothness',
#        'worst concavity', 'worst symmetry', 'worst fractal dimension'],
#       dtype='object')

# %%
data_stan = data_stan.drop('worst texture', axis=1)

# %%
corr = data_stan.corr()
mask = np.triu(np.ones_like(corr, dtype=np.bool))
f, ax = plt.subplots(figsize=(23, 13))
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(corr, annot=True,fmt='.2f',mask=mask, cmap=cmap, ax=ax);

# %%
from sklearn.metrics import f1_score,confusion_matrix,classification_report
from sklearn.metrics import accuracy_score

# %%
from sklearn.model_selection import train_test_split

# %%
data_stan = pd.concat([data_stan, df['target']], axis=1)
data_stan.head()
# Out:
#    mean texture  mean area  mean smoothness  mean concavity  mean symmetry  \
# 0     -2.071512   0.983510         1.567087        2.650542       2.215566
# 1     -0.353322   1.907030        -0.826235       -0.023825       0.001391
# 2      0.455786   1.557513         0.941382        1.362280       0.938859
# 3      0.253509  -0.763792         3.280667        1.914213       2.864862
# 4     -1.150804   1.824624         0.280125        1.369806      -0.009552
#
#    mean fractal dimension  texture error  area error  smoothness error  \
# 0                2.253764      -0.564768    2.485391         -0.213814
# 1               -0.867889      -0.875473    0.741749         -0.604819
# 2               -0.397658      -0.779398    1.180298         -0.296744
# 3                4.906602      -0.110312   -0.288125          0.689095
# 4               -0.561956      -0.789549    1.189310          1.481763
#
#    concavity error  symmetry error  fractal dimension error  worst smoothness  \
# ...

# %%
data_stan['target'] = data_stan['target'].replace({'M':0, 'B':1})
data_stan.head()
# Out:
#    mean texture  mean area  mean smoothness  mean concavity  mean symmetry  \
# 0     -2.071512   0.983510         1.567087        2.650542       2.215566
# 1     -0.353322   1.907030        -0.826235       -0.023825       0.001391
# 2      0.455786   1.557513         0.941382        1.362280       0.938859
# 3      0.253509  -0.763792         3.280667        1.914213       2.864862
# 4     -1.150804   1.824624         0.280125        1.369806      -0.009552
#
#    mean fractal dimension  texture error  area error  smoothness error  \
# 0                2.253764      -0.564768    2.485391         -0.213814
# 1               -0.867889      -0.875473    0.741749         -0.604819
# 2               -0.397658      -0.779398    1.180298         -0.296744
# 3                4.906602      -0.110312   -0.288125          0.689095
# 4               -0.561956      -0.789549    1.189310          1.481763
#
#    concavity error  symmetry error  fractal dimension error  worst smoothness  \
# ...

# %%
corr = data_stan.corr()
mask = np.triu(np.ones_like(corr, dtype=np.bool))
f, ax = plt.subplots(figsize=(23, 13))
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(corr, annot=True,fmt='.2f',mask=mask, cmap=cmap, ax=ax);

# %%
X = data_stan.drop('target', axis=1)
y=data_stan['target']

# %%
X.shape
# Out:
# (569, 16)

# %%
y.shape
# Out:
# (569,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.3,random_state=10)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier()

# %%
params={
    'criterion': ['gini','entropy'],
    'max_depth': range(1,16,2),
    'min_samples_split': range(1,16,2),
    'max_features': range(1,16,2)
}

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
tree_cv = RandomizedSearchCV(dt, params, cv = 5,return_train_score=False )
tree_cv.fit(X, y)
# Out:
# RandomizedSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#                    param_distributions={'criterion': ['gini', 'entropy'],
#                                         'max_depth': range(1, 16, 2),
#                                         'max_features': range(1, 16, 2),
#                                         'min_samples_split': range(1, 16, 2)})

# %%
print("Tuned Decision Tree Parameters: {}".format(tree_cv.best_params_)) 
print("Best score is {}".format(tree_cv.best_score_))
# Out:
# Tuned Decision Tree Parameters: {'min_samples_split': 3, 'max_features': 7, 'max_depth': 15, 'criterion': 'gini'}
# Best score is 0.9419965843813072

# %%
from sklearn.model_selection import GridSearchCV
g_search = GridSearchCV(estimator = dt, param_grid = params, cv = 5, n_jobs = -1, verbose = 0, return_train_score=True)

# %%
g_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': range(1, 16, 2),
#                          'max_features': range(1, 16, 2),
#                          'min_samples_split': range(1, 16, 2)},
#              return_train_score=True)

# %%
print(g_search.best_params_)
# Out:
# {'criterion': 'gini', 'max_depth': 3, 'max_features': 13, 'min_samples_split': 7}

# %%
dt1 = DecisionTreeClassifier(criterion= 'gini', max_depth = 5, max_features= 15, min_samples_split = 11)

# %%
dt1.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, max_features=15, min_samples_split=11)

# %%
y_pred = dt1.predict(X_test)

# %%
accuracy_score(y_pred,y_test)
# Out:
# 0.9239766081871345

# %%
confusion_matrix(y_pred,y_test)
# Out:
# array([[ 53,   7],
#        [  6, 105]], dtype=int64)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.90      0.89        59
#            1       0.95      0.94      0.94       112
#
#     accuracy                           0.92       171
#    macro avg       0.91      0.92      0.92       171
# weighted avg       0.92      0.92      0.92       171

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
par = {
    'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'],
    'penalty': ['none', 'l1', 'l2', 'elasticnet'],
    'C':[100, 10, 1.0, 0.1, 0.01]
}

# %%
tree_cv = RandomizedSearchCV(lr, par, cv = 5,return_train_score=False)
tree_cv.fit(X, y)
# Out:
# RandomizedSearchCV(cv=5, estimator=LogisticRegression(),
#                    param_distributions={'C': [100, 10, 1.0, 0.1, 0.01],
#                                         'penalty': ['none', 'l1', 'l2',
#                                                     'elasticnet'],
#                                         'solver': ['newton-cg', 'lbfgs',
#                                                    'liblinear', 'sag',
#                                                    'saga']})

# %%
print("Tuned Decision Tree Parameters: {}".format(tree_cv.best_params_)) 
print("Best score is {}".format(tree_cv.best_score_))
# Out:
# Tuned Decision Tree Parameters: {'solver': 'sag', 'penalty': 'none', 'C': 10}
# Best score is 0.9718832479428661

# %%
lr = LogisticRegression(solver= 'saga', penalty='l2', C = 1.0)

# %%
lr.fit(X_train,y_train)
# Out:
# LogisticRegression(solver='saga')

# %%
y_pred_lr = lr.predict(X_test)

# %%
confusion_matrix(y_pred_lr,y_test)
# Out:
# array([[ 57,   4],
#        [  2, 108]], dtype=int64)

# %%
from sklearn import metrics

# %%
fpr, tpr, threshold = metrics.roc_curve(y_pred_lr,y_test)

# %%
plt.plot(fpr,tpr)
plt.plot([0, 1], ls="--")
plt.plot([0, 1], c=".7") 
#plt.plot([1, 1] , c=".7")

# %%
from sklearn.metrics import roc_auc_score

# %%
roc_auc_score(y_pred_lr,y_test)
# Out:
# 0.9581222056631894
